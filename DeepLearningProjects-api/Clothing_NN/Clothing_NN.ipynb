# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers,models,datasets

# %% [markdown]
# Neural Network

# %%
fashion_mnist=keras.datasets.fashion_mnist
(train_img,train_lbls),(test_img,test_lbl)=fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
train_img.shape
# Out:
# (60000, 28, 28)

# %%
test_img.shape
# Out:
# (10000, 28, 28)

# %%
test_lbl.shape
# Out:
# (10000,)

# %%
train_img[0,23,23]
# Out:
# 194

# %%
train_lbls[:20]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, 9, 1, 0, 6, 4],
#       dtype=uint8)

# %%
plt.figure()
plt.imshow(train_img[1])
plt.show()

# %%
plt.figure()
plt.imshow(train_img[4])
plt.show()

# %%
plt.figure()
plt.imshow(train_img[0])
plt.show()

# %%
class_names=['T-shirt/Top','Trouser','Pullover','Dress','Coat',
             'Sandels','Shirt','Sneaker','Bag','Ankle boot']

# %%
train_img=train_img/255.0
test_img=test_img/255.0

# %%
model=keras.Sequential([
        keras.layers.Flatten(input_shape=(28,28)),
        keras.layers.Dense(128,activation='sigmoid'),
        keras.layers.Dense(100,activation='sigmoid'),
        keras.layers.Dense(50,activation='sigmoid'),
        keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_img, train_lbls, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7057 - accuracy: 0.7622
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4008 - accuracy: 0.8563
# Epoch 3/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3563 - accuracy: 0.8725
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3298 - accuracy: 0.8809
# Epoch 5/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3097 - accuracy: 0.8870
# Epoch 6/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2963 - accuracy: 0.8925
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2847 - accuracy: 0.8960
# Epoch 8/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2737 - accuracy: 0.8996
# Epoch 9/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2623 - accuracy: 0.9042
# Epoch 10/20
# ...

# %%
model.evaluate(test_img,test_lbl)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3580 - accuracy: 0.8809
# [0.35801514983177185, 0.8809000253677368]

# %%
predictions=model.predict(test_img)
print(class_names[np.argmax(predictions[0])])
plt.figure()
plt.imshow(test_img[0])
plt.show()
# Out:
# Ankle boot

# %%
predictions=model.predict(test_img)
print(class_names[np.argmax(predictions[49])])
plt.figure()
plt.imshow(test_img[49])
plt.show()
# Out:
# Pullover

# %%
predictions=model.predict(test_img)
print(class_names[np.argmax(predictions[1000])])
plt.figure()
plt.imshow(test_img[1000])
plt.show()
# Out:
# Shirt

# %%
predictions=model.predict(test_img)
print(class_names[np.argmax(predictions[45])])
plt.figure()
plt.imshow(test_img[45])
plt.show()
# Out:
# Sneaker
